# %%
'''Guiao5'''

import sklearn as skl
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#USING CROSS VALIDATION
from sklearn.model_selection import cross_val_score
from sklearn.datasets import load_breast_cancer

cancer= load_breast_cancer()

cancer.keys()

cancer['feature_names']

df_feat = pd.DataFrame(cancer['data'],columns=cancer['feature_names'])
#df_feat.info()

cancer['target']

#target é a label
df_target = pd.DataFrame(cancer['target'],columns=['Cancer'])

df_target.head()

#sns.pairplot(df_target)

#sns.heatmap(df_target)

#boxplots
#ax= sns.boxplot(x=df_feat['mean radius'])
#ax= sns.boxplot(x=df_feat['mean radius'],y=df_feat['area error'])

#matriz de correlacao
#corr_matrix= df_feat.corr()
#f, ax =plt.subplots(figsize=(8,6))
#sns.heatmap(corr_matrix,vmin=1,vmax=1,square=True,annot=True)

from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

cross_valid_model = SVC(random_state=2021)
scores= cross_val_score(cross_valid_model, df_feat, np.ravel(df_target),cv=10)
scores

#print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))


#train test split

x_train, x_test, y_train, y_test = train_test_split(df_feat, np.ravel(df_target), test_size=0.30, random_state=2021)

#verificar equilibro dos dados na fatia de treino e na fatia de teste
#to do

sns.set_style('whitegrid')
#sns.countplot(x='Cancer', data = pd.DataFrame(y_train,columns=['Cancer']),palette='RdBu_r')

#sns.countplot(x='Cancer', data = pd.DataFrame(y_test,columns=['Cancer']),palette='RdBu_r')


#hold out model

model = SVC(random_state=2021)
model.fit(x_train,y_train)

predictions = model.predict(x_test)
#print("%0.2f accuracy" % (accuracy_score(y_test, predictions)))

#plot_confusion_matrix(model, x_test, y_test)

#print(classification_report(y_test,predictions))

#gridsearch - ferramenta para procurar melhores valores de hyperparametros para meslhores resultados do modelo

param_grid={'C':[0.25,0.5,1,1.25,1.5], 'gamma':[0.00005,0.000075,0.0001,0.000125,0.00015],'kernel': ['rbf']}

from sklearn.model_selection import GridSearchCV

grid= GridSearchCV(SVC(random_state=2021),param_grid,refit=True,verbose=3)

grid.fit(x_train,y_train)

grid.best_params_

grid.best_estimator_

#plot_confusion_matrix(grid, x_test, y_test)

#grid_predictions = grid.predict(x_test)
#print(classification_report(y_test,grid_predictions))
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ...C=0.25, gamma=5e-05, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ...C=0.25, gamma=5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 3/5] END ...C=0.25, gamma=5e-05, kernel=rbf;, score=0.938 total time=   0.0s
# [CV 4/5] END ...C=0.25, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END ...C=0.25, gamma=5e-05, kernel=rbf;, score=0.924 total time=   0.0s
# [CV 1/5] END .C=0.25, gamma=7.5e-05, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=0.25, gamma=7.5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END .C=0.25, gamma=7.5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .C=0.25, gamma=7.5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END .C=0.25, gamma=7.5e-05, kernel=rbf;, score=0.924 total time=   0.0s
# [CV 1/5] END ..C=0.25, gamma=0.0001, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ..C=0.25, gamma=0.0001, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END ..C=0.25, gamma=0.0001, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ..C=0.25, gamma=0.0001, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END ..C=0.25, gamma=0.0001, kernel=rbf;, score=0.924 total time=   0.0s
# [CV 1/5] END C=0.25, gamma=0.000125, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END C=0.25, gamma=0.000125, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END C=0.25, gamma=0.000125, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END C=0.25, gamma=0.000125, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END C=0.25, gamma=0.000125, kernel=rbf;, score=0.937 total time=   0.0s
# [CV 1/5] END .C=0.25, gamma=0.00015, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END .C=0.25, gamma=0.00015, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END .C=0.25, gamma=0.00015, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .C=0.25, gamma=0.00015, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END .C=0.25, gamma=0.00015, kernel=rbf;, score=0.937 total time=   0.0s
# [CV 1/5] END ....C=0.5, gamma=5e-05, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ....C=0.5, gamma=5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ....C=0.5, gamma=5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ....C=0.5, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END ....C=0.5, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ..C=0.5, gamma=7.5e-05, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ..C=0.5, gamma=7.5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ..C=0.5, gamma=7.5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ..C=0.5, gamma=7.5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END ..C=0.5, gamma=7.5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ...C=0.5, gamma=0.0001, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ...C=0.5, gamma=0.0001, kernel=rbf;, score=0.975 total time=   0.0s
# [CV 3/5] END ...C=0.5, gamma=0.0001, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ...C=0.5, gamma=0.0001, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ...C=0.5, gamma=0.0001, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 1/5] END .C=0.5, gamma=0.000125, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=0.5, gamma=0.000125, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END .C=0.5, gamma=0.000125, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .C=0.5, gamma=0.000125, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END .C=0.5, gamma=0.000125, kernel=rbf;, score=0.924 total time=   0.0s
# [CV 1/5] END ..C=0.5, gamma=0.00015, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ..C=0.5, gamma=0.00015, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END ..C=0.5, gamma=0.00015, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ..C=0.5, gamma=0.00015, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ..C=0.5, gamma=0.00015, kernel=rbf;, score=0.924 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=5e-05, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=5e-05, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=7.5e-05, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=7.5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=7.5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=7.5e-05, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=7.5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.000125, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.000125, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.000125, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.000125, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.000125, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.00015, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.00015, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.00015, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.00015, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.00015, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ...C=1.25, gamma=5e-05, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ...C=1.25, gamma=5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ...C=1.25, gamma=5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ...C=1.25, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 5/5] END ...C=1.25, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END .C=1.25, gamma=7.5e-05, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=1.25, gamma=7.5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END .C=1.25, gamma=7.5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .C=1.25, gamma=7.5e-05, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END .C=1.25, gamma=7.5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ..C=1.25, gamma=0.0001, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ..C=1.25, gamma=0.0001, kernel=rbf;, score=0.975 total time=   0.0s
# [CV 3/5] END ..C=1.25, gamma=0.0001, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ..C=1.25, gamma=0.0001, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ..C=1.25, gamma=0.0001, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END C=1.25, gamma=0.000125, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END C=1.25, gamma=0.000125, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END C=1.25, gamma=0.000125, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END C=1.25, gamma=0.000125, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END C=1.25, gamma=0.000125, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END .C=1.25, gamma=0.00015, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=1.25, gamma=0.00015, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5] END .C=1.25, gamma=0.00015, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .C=1.25, gamma=0.00015, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END .C=1.25, gamma=0.00015, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ....C=1.5, gamma=5e-05, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 2/5] END ....C=1.5, gamma=5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ....C=1.5, gamma=5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ....C=1.5, gamma=5e-05, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ....C=1.5, gamma=5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ..C=1.5, gamma=7.5e-05, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ..C=1.5, gamma=7.5e-05, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ..C=1.5, gamma=7.5e-05, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ..C=1.5, gamma=7.5e-05, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ..C=1.5, gamma=7.5e-05, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ...C=1.5, gamma=0.0001, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ...C=1.5, gamma=0.0001, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END ...C=1.5, gamma=0.0001, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ...C=1.5, gamma=0.0001, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ...C=1.5, gamma=0.0001, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END .C=1.5, gamma=0.000125, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=1.5, gamma=0.000125, kernel=rbf;, score=0.975 total time=   0.0s
# [CV 3/5] END .C=1.5, gamma=0.000125, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END .C=1.5, gamma=0.000125, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END .C=1.5, gamma=0.000125, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 1/5] END ..C=1.5, gamma=0.00015, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 2/5] END ..C=1.5, gamma=0.00015, kernel=rbf;, score=0.975 total time=   0.0s
# [CV 3/5] END ..C=1.5, gamma=0.00015, kernel=rbf;, score=0.950 total time=   0.0s
# [CV 4/5] END ..C=1.5, gamma=0.00015, kernel=rbf;, score=0.911 total time=   0.0s
# [CV 5/5] END ..C=1.5, gamma=0.00015, kernel=rbf;, score=0.899 total time=   0.0s
# SVC(C=0.25, gamma=0.000125, random_state=2021)

# %%
grid_predictions = grid.predict(x_test)
print(grid_predictions)
